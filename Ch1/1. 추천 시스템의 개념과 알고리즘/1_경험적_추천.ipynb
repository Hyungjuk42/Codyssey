# %% [markdown]
# - 데이터는 제공되는 파일인 prob-0101.csv를 사용한다.
# - 영화 개수, 배급사 수, 감독 수, 출연진 수, 장르 수를 파악한다.
# - 감독, 출연진 등 중복 조건들에 대해 파악한다.
# - 본인이 추천하고 싶은 기준을 설정한다.
# - 본인의 기준에 의해 영화 몇개를 추천하는 것이 적당한지 실험해 본다.
# - 다양한 접근 조회 방법을 실험한다. (감독, 출연진 중복, 장르별 등)
# - 개인별로 정한 기준이 서로 어떻게 다른지 확인한다.

# %%
import pandas as pd

file_path = './prob-0101.csv'
df = pd.read_csv(file_path)

print(f'전체 데이터 수 : {len(df)}')

column_list = df.columns.tolist()
column_list
# Out:
# 전체 데이터 수 : 59
# ['개봉일', '제목', '배급사', '감독', '출연진', '장르']

# %%
import re

without_dup_items = dict()
without_dup_num = dict()

def split_and_eleminate_by_char(item: str, seperator: str) -> set:
    pattern = f"[{re.escape(seperator)}]+"
    item_in_list = re.split(pattern, item)
    item_set = set(item_in_list)
    if (len(item_set) == 1 and '' in item_set):
        return None
    return item_set
    

def split_and_eleminate_set_by_char(item_set: set, seperator: str) -> set:
    result = set()
    for item in item_set:
        new_set = split_and_eleminate_by_char(item, seperator)
        result.update(new_set) if new_set != None else None
    return result



for column in column_list:
    unique_values = df[column].nunique(dropna=True)
    print(f'단순히 중복되지 않은 {column} 수 : {unique_values}')
    without_dup_item = set(df[column])
    if column == "출연진" :
        without_dup_item = split_and_eleminate_set_by_char(without_dup_item, ", ")
    if column == "장르" :
        without_dup_item = split_and_eleminate_set_by_char(without_dup_item, ", ·/")
    print(len(without_dup_item), without_dup_item)
    without_dup_num[column] = len(without_dup_item)
    without_dup_items[column] = without_dup_item
    # print(df[column][~df[column].duplicated(keep=False)])
# Out:
# 단순히 중복되지 않은 개봉일 수 : 32
# 32 {'2023-04-06', '2023-05-24', '2023-05-18', '2023-01-25', '2023-02-23', '2023-06-28', '2023-06-07', '2023-05-17', '2023-06-08', '2023-02-08', '2023-04-26', '2023-01-18', '2023-02-17', '2023-06-14', '2023-04-12', '2023-03-23', '2023-03-01', '2023-01-12', '2023-02-22', '2023-05-10', '2023-03-08', '2023-01-05', '2023-04-27', '2023-04-14', '2023-03-15', '2023-01-04', '2023-04-19', '2023-05-31', '2023-04-05', '2023-06-21', '2023-03-29', '2023-01-20'}
# 단순히 중복되지 않은 제목 수 : 59
# 59 {'스프린터', '말이야 바른 말이지', '강남좀비', '안나푸르나', '인드림', '솔라 플라워', '찬란한 나의 복수', '바람개비', '범죄도시 3', '드림', '아수라장: 범털들의 전쟁', '물안에서', '튤립 모양', '육지것들', '정이', '라방', '스위치', '드림팰리스', '리바운드', '살수', '별 볼일 없는 인생', '낭만적 공장', '열여덟, 어른이 되는 나이', '다음 소희', '멍뭉이', '우리 사랑이 향기로 남을 때', '카운트', '흐르다', '나는 여기에 있다', '낭만 캠퍼스', '여섯 개의 밤', '여덟 번째 감각', '유령', '남자는 처음을 원하고 여자는 마지막을 원한다', '소울메이트', '웅남이', '사랑의 고고학', '실버맨', '2퍼센트', '밥만 잘 사주는 이상한 이사님 극장판', '컨버세이션', '장기자랑', '박하경 여행기', '롱디', '불멸의 여자', '익스트림 페스티벌', '대외비', '어쩌면 우린 헤어졌는지 모른다', '보이지 않아', '10일간의 애인', '제비', '스트리머', '킬링 로맨스', '스마트폰을 떨어뜨렸을 뿐인데', '귀공자', '오늘 출가합니다', '손', '그대 어이가리', '교섭'}
# 단순히 중복되지 않은 배급사 수 : 52
# 52 {'(주)제이앤씨미디어그룹', '(주)엣나인필름', '와이드릴리즈(주)', '(주)바른손이앤아이', '(주)영화특별시 에스엠씨', '(주)CJ CGV', '(주)영화사 진진', '(주)와이드릴리즈', '영화배급협동조합 씨네소파', '(주)콘텐츠윙', '드림팩트엔터테인먼트', '㈜스토리제이', '(주)스토리제이', 'CJ엔터테인먼트', '(주)이눌미디어', '(주)원더스튜디오', '영화제작전원사, 콘텐츠판다', '롯데컬처웍스, (주)롯데엔터테인먼트', '(주)트리플픽쳐스', '(주)시네마달', 'CJ CGV', '(주)영화사오윈', '(주)플레이그램', '(주)CJ ENM', '(주)콘텐츠존, (주)다자인소프트', '(주)넥스트엔터테인먼트월드', '(주)인디스토리', '삼거리픽쳐스', '(주)넥스트엔터테인먼트', '트윈플러스파트너스(주)', '(주)플렉스엠엔터테인먼트', '(주)디스테이션', '씨에스픽쳐스', '(주)에이비오엔터테인먼트', '(주)이놀미디어', '스튜디오 에이드', '시네마 뉴원', '시네마뉴원', '트윈플러스파트너스', '(주)그노스', '(주)영화사 순수', '트리플픽쳐스', '(주)씨엠닉스', '플렉스엠엔터테인먼트', '필름 다빈', '아웃런브라더스픽쳐스', 'TCO(주)더콘텐츠온', 'M&M 인터내셔널', '넷플릭스', '플러스엠엔터테인먼트', '(주)와이웍스엔터테인먼트', '롯데컬쳐웍스 (주)롯데엔터테인먼트'}
# 단순히 중복되지 않은 감독 수 : 58
# 58 {'이송희일', '이상훈', '이소현', '신재호', '주영', '박동기', '황승제', '장항준', '양경희', '이황', '임재완', '김홍기', '박훈정', '윤여창', '조은성', '권혁재', '이영용', '김덕중', '김태준', '신근호', '이창열', '이종필', '한경탁', '김현정', '김주환', '이상용', '임순례', '최윤호', '임성운', '이현준', '이해영', '배인우', '최종태', '박성광', '가성문', '서동현', '이병헌', '이수성', '민용근', '곽정덕', '최주연', '홍상수', '최세환', '형슬우', '이원석', '임성용', '장형모', '마대윤', '정주리', '연상호', '이원태', '최승연', '[1]', '이완민', '문신구', '양윤모', '김성환', '최창환'}
# 단순히 중복되지 않은 출연진 수 : 59
# 263 {'심소영', '이대연', '김강현', '김경일', '안미나', '차태현', '신석호', '김종수', '이한주', '임지섭', '장동윤', '김선영', '윤가현', '이설구', '김우겸', '정병훈', '김도현', '이윤지', '이나영', '하성국', '정혜인', '임지호', '장영준', '유연석', '박수영', '서지안', '송덕호', '고규필', '한가은', '윤시윤', '김민희', '한규원', '이규복', '박종진', '설인아', '이민정', '김수하', '이선균', '김소령', '이노아', '오정세', '장동주', '허준석', '무네타카', '박정우', '문희경', '김정팔', '이음', '박서준', '정미미', '최지연', '박성일', '박해인', '윤박', '정아미', '서은채', '한승도', '박소진', '양한열', '문지인', '유지애', '김시은', '방진원', '김민경', '신애리', '이푸름', '박영훈', '신의현', '변우석', '노상현', '홍완표', '오준택', '한태경', '박소이', '강길우', '김모범', '나현준', '오달수', '조수빈', '이하늬', '정다은', '남명렬', '신민재', '최성원', '한다솔', '이영석', '김소형', '설유진', '조윤서', '안재홍', '배진아', '김영웅', '진혜원', '전석호', '김승수', '류경수', '최동구', '송보은', '윤성모', '김준형', '성유빈', '김민재', '백수련', '이현우', '지연', '강수연', '박혜영', '이장유', '박정철', '정인기', '박유신', '곽민규', '김동희', '양현민', '박현숙', '최우준', '이문식', '전소니', '서벽준', '아오키', '박유나', '서현우', '강진아', '옥자연', '조진웅', '이동휘', '이이경', '김도건', '이설', '정수지', '곽진무', '최민수', '조민재', '조한선', '우지현', '박동기', '신연서', '고아라', '정은채', '강태주', '김명찬', '정수하', '노지유', '유다인', '오경화', '신사랑', '김봉주', '신현준', '김민', '김정균', '이경준', '서효림', '정가은', '정영주', '김상욱', '박지수', '조은지', '이경욱', '염혜란', '이성민', '김승윤', '심영은', '최민영', '지일주', '황정민', '남보라', '권상우', '전신환', '김희원', '허지나', '채수아', '양홍주', '김준', '이태규', '박강섭', '현빈', '하민호', '한수연', '박해수', '홍은기', '서지희', '송은지', '천우희', '정태우', '박소감', '박호산', '서동원', '유인수', '김순덕', '윤제문', '정지운', '김강우', '마동석', '아이유', '이세호', '최준혁', '진선규', '박상욱', '홍준영', '소이', '이미경', '오지호', '이지훈', '박순천', '공민정', '현진영', '심현탁', '김소희', '김현주', '박성웅', '배누리', '전혜진', '노수산나', '김무열', '김명임', '김선호', '박우영', '인내상', '임시완', '박선호', '서지후', '이지용', '이지원', '이범수', '장희령', '변중희', '김다미', '강기영', '정승길', '임선우', '설경구', '선동혁', '오나라', '오원빈', '강윤', '안세호', '장원혁', '김용준', '백지혜', '이준혁', '이재원', '박미현', '김다현', '기윤', '허웅', '송민경', '이원석', '심희섭', '고창석', '차선우', '박종환', '김희정', '공명', '정서하', '권민혁', '김기호', '김재화', '정유연', '배두나', '김세환', '안수호', '이용녀', '유재인'}
# 단순히 중복되지 않은 장르 수 : 20
# 14 {'SF', '범죄', '미스터리', '드라마', '로맨스', '스럴리', '스릴러', '멜로', '가족', '공포', '기타', '코미디', '다큐멘터리', '액션'}

# %% [markdown]
# - 감독, 출연진, 장르를 기준으로
# - 상위 20%
# - 검색 방식 만들기

# %%
# 파싱한 새로운 column 추가하기

df['parsed_actor'] = df['출연진'].apply(lambda x: split_and_eleminate_by_char(x, ", "))
df['parsed_genre'] = df['장르'].apply(lambda x: split_and_eleminate_by_char(x, ", ·/"))
df['parsed_director'] = df['감독'].apply(lambda x: split_and_eleminate_by_char(x, ", ·/"))

# %%
from typing import TypedDict

class State(TypedDict):
    actor: set[str]
    genre: set[str]
    director: set[str]

def 영화_경험_추천():
    state: State = {}
    state["actor"] = split_and_eleminate_by_char(input("선호하는 배우들을 알려주세요. Ex) 전재준, 박연진, 이사라"), ", ·/")
    state["genre"] = split_and_eleminate_by_char(input("선호하는 장르를 알려주세요. Ex) 로맨스, 공포"), ", ·/")
    state["director"] = split_and_eleminate_by_char(input("선호하는 감독을 알려주세요. Ex) 봉준호"), ", ·/")
    keys = ["actor", "genre", "director"]
    for key in keys:
        if not state.get(key):
            continue
        for value in state.get(key):
            filtered_row = df[df[f"parsed_{key}"].apply(lambda x: value in x)]
            print(f"--- FILTERED {key} ---\n", filtered_row.head(10))

영화_경험_추천()
# Out:
# --- FILTERED actor ---
#             개봉일  제목           배급사   감독       출연진          장르 parsed_actor  \
# 41  2023-05-10  롱디  (주)넥스트엔터테인먼트  임재완  장동윤, 박유나  멜로·로맨스·코미디   {장동윤, 박유나}
#
#       parsed_genre parsed_director
# 41  {로맨스, 멜로, 코미디}           {임재완}
# --- FILTERED genre ---
#             개봉일                        제목                 배급사   감독  \
# 2   2023-01-12                별 볼일 없는 인생            (주)이놀미디어  서동현
# 3   2023-01-12                  10일간의 애인              (주)그노스  이영용
# 10  2023-02-08           우리 사랑이 향기로 남을 때  (주)콘텐츠존, (주)다자인소프트  임성용
# 20  2023-03-29                   여섯 개의 밤            (주)인디스토리  최창환
# 21  2023-03-29                  여덟 번째 감각            (주)플레이그램  배인우
# 29  2023-04-06                    솔라 플라워              ㈜스토리제이  한경탁
# 37  2023-04-19                    낭만적 공장            (주)영화사오윈  조은성
# 41  2023-05-10                        롱디        (주)넥스트엔터테인먼트  임재완
# 45  2023-05-18  남자는 처음을 원하고 여자는 마지막을 원한다            (주)스토리제이  이현준
#
#                                            출연진               장르  \
# 2                                          정가은           멜로/로맨스
# 3                                          송민경           멜로/로맨스
# 10                윤시윤, 설인아, 노상현, 문지인, 이규복, 김영웅       멜로·로맨스·코미디
# 20                강길우, 강진아, 김시은, 변중희, 이한주, 정수지  드라마, 멜로·로맨스, 가족
# 21           오준택, 임지섭, 박해인, 장영준, 방진원, 서지안, 채수아           멜로·로맨스
# 29  오원빈, 서지희, 심현탁, 박정철, 김수하, 김민, 김봉주, 조수빈, 정병훈       멜로,로맨스,드라마
# 37                          심희섭, 전혜진, 한승도, 박수영           멜로·로맨스
# 41                                    장동윤, 박유나       멜로·로맨스·코미디
# 45                               윤성모, 정미미, 장원혁           멜로·로맨스
#
#                                     parsed_actor        parsed_genre  \
# 2                                          {정가은}           {로맨스, 멜로}
# 3                                          {송민경}           {로맨스, 멜로}
# 10                {노상현, 이규복, 설인아, 김영웅, 문지인, 윤시윤}      {로맨스, 멜로, 코미디}
# 20                {강진아, 이한주, 강길우, 변중희, 김시은, 정수지}  {로맨스, 멜로, 가족, 드라마}
# 21           {장영준, 오준택, 채수아, 박해인, 임지섭, 서지안, 방진원}           {로맨스, 멜로}
# 29  {오원빈, 김봉주, 서지희, 김민, 박정철, 김수하, 심현탁, 조수빈, 정병훈}      {로맨스, 멜로, 드라마}
# 37                          {심희섭, 한승도, 전혜진, 박수영}           {로맨스, 멜로}
# 41                                    {장동윤, 박유나}      {로맨스, 멜로, 코미디}
# 45                               {장원혁, 정미미, 윤성모}           {로맨스, 멜로}
#
#    parsed_director
# 2            {서동현}
# 3            {이영용}
# 10           {임성용}
# 20           {최창환}
# 21           {배인우}
# 29           {한경탁}
# 37           {조은성}
# 41           {임재완}
# 45           {이현준}
# --- FILTERED genre ---
#             개봉일                제목            배급사   감독  \
# 1   2023-01-05              강남좀비      (주)와이드릴리즈  이수성
# 4   2023-01-18                교섭     플렉스엠엔터테인먼트  임순례
# 7   2023-01-25    열여덟, 어른이 되는 나이          필름 다빈   주영
# 8   2023-02-08             다음 소희      트윈플러스파트너스  정주리
# 9   2023-02-08  어쩌면 우린 헤어졌는지 모른다  (주)영화특별시 에스엠씨  형슬우
# 12  2023-02-22               카운트      (주)CJ ENM  권혁재
# 14  2023-02-23             컨버세이션          필름 다빈  김덕중
# 15  2023-03-01               멍뭉이  (주)와이웍스엔터테인먼트  김주환
# 16  2023-03-01               대외비     플러스엠엔터테인먼트  이원태
# 17  2023-03-08           그대 어이가리      (주)영화사 순수  이창열
#
#                              출연진       장르                    parsed_actor  \
# 1                        지일주, 지연      드라마                       {지연, 지일주}
# 4                   황정민, 현빈, 강기영      드라마                  {황정민, 현빈, 강기영}
# 7             임선우, 김명찬, 이장유, 박현숙      드라마            {김명찬, 임선우, 박현숙, 이장유}
# 8             김시은, 배두나, 박우영, 정수하      드라마            {박우영, 정수하, 김시은, 배두나}
# 9             이동휘, 정은채, 강길우, 정다은      드라마            {이동휘, 정은채, 정다은, 강길우}
# 12  진선규, 성유빈, 오나라, 고창석, 장동주, 고규필      드라마  {오나라, 진선규, 고창석, 장동주, 고규필, 성유빈}
# 14   조은지, 박종환, 곽민규, 소이, 송은지, 곽진무      드라마   {송은지, 소이, 박종환, 곽민규, 조은지, 곽진무}
# 15                      유연석, 차태현      드라마                      {유연석, 차태현}
# 16                 조진웅, 이성민, 김무열  범죄, 드라마                 {김무열, 조진웅, 이성민}
# 17                 선동혁, 정아미, 박종진      드라마                 {선동혁, 정아미, 박종진}
#
#    parsed_genre parsed_director
# 1         {드라마}           {이수성}
# 4         {드라마}           {임순례}
# 7         {드라마}            {주영}
# 8         {드라마}           {정주리}
# 9         {드라마}           {형슬우}
# 12        {드라마}           {권혁재}
# 14        {드라마}           {김덕중}
# 15        {드라마}           {김주환}
# 16    {범죄, 드라마}           {이원태}
# 17        {드라마}           {이창열}
