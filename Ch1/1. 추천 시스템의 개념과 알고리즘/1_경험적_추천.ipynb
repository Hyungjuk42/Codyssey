# %% [markdown]
# - 데이터는 제공되는 파일인 prob-0101.csv를 사용한다.
# - 영화 개수, 배급사 수, 감독 수, 출연진 수, 장르 수를 파악한다.
# - 감독, 출연진 등 중복 조건들에 대해 파악한다.
# - 본인이 추천하고 싶은 기준을 설정한다.
# - 본인의 기준에 의해 영화 몇개를 추천하는 것이 적당한지 실험해 본다.
# - 다양한 접근 조회 방법을 실험한다. (감독, 출연진 중복, 장르별 등)
# - 개인별로 정한 기준이 서로 어떻게 다른지 확인한다.

# %%
import pandas as pd

file_path = './prob-0101.csv'
df = pd.read_csv(file_path)

print(f'전체 데이터 수 : {len(df)}')

column_list = df.columns.tolist()
column_list
# Out:
# 전체 데이터 수 : 59
# ['개봉일', '제목', '배급사', '감독', '출연진', '장르']

# %%
import re

without_dup_items = dict()
without_dup_num = dict()

def split_and_eleminate_by_char(item: str, seperator: str) -> set:
    pattern = f"[{re.escape(seperator)}]+"
    item_in_list = re.split(pattern, item)
    item_set = set(item_in_list)
    if (len(item_set) == 1 and '' in item_set):
        return None
    return item_set
    

def split_and_eleminate_set_by_char(item_set: set, seperator: str) -> set:
    result = set()
    for item in item_set:
        new_set = split_and_eleminate_by_char(item, seperator)
        result.update(new_set) if new_set != None else None
    return result



for column in column_list:
    unique_values = df[column].nunique(dropna=True)
    print(f'단순히 중복되지 않은 {column} 수 : {unique_values}')
    without_dup_item = set(df[column])
    if column == "출연진" :
        without_dup_item = split_and_eleminate_set_by_char(without_dup_item, ", ")
    if column == "장르" :
        without_dup_item = split_and_eleminate_set_by_char(without_dup_item, ", ·/")
    print(len(without_dup_item), without_dup_item)
    without_dup_num[column] = len(without_dup_item)
    without_dup_items[column] = without_dup_item
    # print(df[column][~df[column].duplicated(keep=False)])
# Out:
# 단순히 중복되지 않은 개봉일 수 : 32
# 32 {'2023-02-08', '2023-03-23', '2023-04-19', '2023-06-07', '2023-06-21', '2023-01-18', '2023-04-26', '2023-01-04', '2023-03-15', '2023-06-08', '2023-04-06', '2023-04-12', '2023-04-14', '2023-02-22', '2023-05-18', '2023-05-10', '2023-05-24', '2023-03-08', '2023-05-31', '2023-06-28', '2023-04-05', '2023-02-17', '2023-05-17', '2023-06-14', '2023-04-27', '2023-01-12', '2023-02-23', '2023-03-01', '2023-03-29', '2023-01-05', '2023-01-25', '2023-01-20'}
# 단순히 중복되지 않은 제목 수 : 59
# 59 {'낭만 캠퍼스', '장기자랑', '스마트폰을 떨어뜨렸을 뿐인데', '스트리머', '드림팰리스', '별 볼일 없는 인생', '리바운드', '소울메이트', '불멸의 여자', '정이', '살수', '여덟 번째 감각', '강남좀비', '찬란한 나의 복수', '솔라 플라워', '열여덟, 어른이 되는 나이', '아수라장: 범털들의 전쟁', '남자는 처음을 원하고 여자는 마지막을 원한다', '대외비', '유령', '보이지 않아', '익스트림 페스티벌', '다음 소희', '우리 사랑이 향기로 남을 때', '범죄도시 3', '멍뭉이', '귀공자', '인드림', '10일간의 애인', '튤립 모양', '2퍼센트', '여섯 개의 밤', '웅남이', '밥만 잘 사주는 이상한 이사님 극장판', '그대 어이가리', '어쩌면 우린 헤어졌는지 모른다', '흐르다', '컨버세이션', '오늘 출가합니다', '카운트', '말이야 바른 말이지', '육지것들', '나는 여기에 있다', '바람개비', '손', '라방', '사랑의 고고학', '제비', '킬링 로맨스', '물안에서', '낭만적 공장', '교섭', '박하경 여행기', '드림', '스프린터', '실버맨', '스위치', '안나푸르나', '롱디'}
# 단순히 중복되지 않은 배급사 수 : 52
# 52 {'(주)영화특별시 에스엠씨', '(주)콘텐츠윙', '와이드릴리즈(주)', '(주)영화사 순수', '(주)인디스토리', '㈜스토리제이', 'M&M 인터내셔널', '(주)와이웍스엔터테인먼트', '(주)에이비오엔터테인먼트', '트윈플러스파트너스', '(주)그노스', '시네마뉴원', '씨에스픽쳐스', '삼거리픽쳐스', '아웃런브라더스픽쳐스', '(주)영화사 진진', '드림팩트엔터테인먼트', '영화제작전원사, 콘텐츠판다', 'CJ엔터테인먼트', '(주)원더스튜디오', '플러스엠엔터테인먼트', '영화배급협동조합 씨네소파', '(주)시네마달', '(주)스토리제이', '(주)플렉스엠엔터테인먼트', '(주)와이드릴리즈', '(주)바른손이앤아이', '롯데컬쳐웍스 (주)롯데엔터테인먼트', '시네마 뉴원', 'CJ CGV', '(주)이놀미디어', '(주)넥스트엔터테인먼트', '(주)트리플픽쳐스', '(주)이눌미디어', '(주)CJ CGV', '(주)엣나인필름', '(주)플레이그램', '넷플릭스', '트윈플러스파트너스(주)', '(주)씨엠닉스', '롯데컬처웍스, (주)롯데엔터테인먼트', '플렉스엠엔터테인먼트', '(주)디스테이션', '(주)영화사오윈', '필름 다빈', '스튜디오 에이드', 'TCO(주)더콘텐츠온', '(주)CJ ENM', '(주)콘텐츠존, (주)다자인소프트', '(주)제이앤씨미디어그룹', '(주)넥스트엔터테인먼트월드', '트리플픽쳐스'}
# 단순히 중복되지 않은 감독 수 : 58
# 58 {'임성용', '장항준', '양경희', '정주리', '한경탁', '이종필', '장형모', '이병헌', '민용근', '윤여창', '최주연', '이황', '문신구', '김홍기', '김성환', '김현정', '이상용', '[1]', '박성광', '임재완', '신재호', '최창환', '이원석', '박훈정', '이송희일', '이완민', '최세환', '이해영', '이소현', '이현준', '박동기', '이원태', '권혁재', '조은성', '이영용', '최승연', '마대윤', '형슬우', '김덕중', '양윤모', '임순례', '황승제', '배인우', '연상호', '김태준', '최종태', '이창열', '신근호', '이수성', '임성운', '이상훈', '가성문', '주영', '홍상수', '최윤호', '김주환', '서동현', '곽정덕'}
# 단순히 중복되지 않은 출연진 수 : 59
# 263 {'정지운', '이동휘', '김무열', '정혜인', '박현숙', '오나라', '문지인', '이민정', '현빈', '이이경', '김강현', '노수산나', '허지나', '공명', '정수지', '천우희', '정서하', '박종진', '김우겸', '김다현', '신민재', '박순천', '정영주', '김동희', '이미경', '신연서', '김다미', '김희원', '심소영', '백지혜', '하민호', '우지현', '조수빈', '한승도', '최민수', '강기영', '박종환', '송은지', '배진아', '김세환', '김정균', '노상현', '서은채', '이한주', '성유빈', '김명임', '박선호', '공민정', '진선규', '신현준', '강수연', '윤박', '김현주', '박미현', '이설', '류경수', '백수련', '김희정', '설유진', '이세호', '방진원', '이태규', '이지원', '이지용', '설경구', '이문식', '김민희', '박정우', '허웅', '인내상', '지일주', '오지호', '윤가현', '박성일', '김상욱', '이영석', '한규원', '이준혁', '무네타카', '박유나', '채수아', '장동윤', '최민영', '송보은', '이장유', '박성웅', '김봉주', '소이', '남보라', '김강우', '김소령', '김재화', '임시완', '서벽준', '박우영', '정아미', '이경준', '정병훈', '안세호', '이규복', '김선영', '신석호', '김민', '박해인', '심현탁', '양현민', '황정민', '정인기', '이용녀', '오원빈', '박소진', '박해수', '임지섭', '김기호', '기윤', '김시은', '정다은', '김경일', '윤성모', '김순덕', '옥자연', '조한선', '차선우', '최성원', '김소형', '최우준', '안미나', '오정세', '박유신', '조민재', '박강섭', '김승수', '김정팔', '김민경', '강길우', '진혜원', '설인아', '노지유', '장동주', '이음', '강윤', '신의현', '임지호', '최동구', '고창석', '오경화', '곽민규', '이선균', '유지애', '이설구', '오준택', '조은지', '서지희', '박서준', '박영훈', '박지수', '권민혁', '배두나', '김종수', '박상욱', '권상우', '이지훈', '허준석', '이현우', '양홍주', '이원석', '마동석', '이나영', '이하늬', '유다인', '서현우', '임선우', '유재인', '김도현', '서동원', '박동기', '홍은기', '이대연', '선동혁', '조진웅', '김준', '전소니', '정가은', '정태우', '장원혁', '정유연', '김민재', '최준혁', '전혜진', '한가은', '심영은', '전석호', '김용준', '남명렬', '유인수', '정수하', '김수하', '나현준', '박소감', '안수호', '지연', '신사랑', '강태주', '김명찬', '이재원', '현진영', '박호산', '정승길', '김도건', '홍완표', '이윤지', '박정철', '서지안', '윤시윤', '김승윤', '염혜란', '변중희', '이노아', '곽진무', '이성민', '홍준영', '김모범', '변우석', '고아라', '정미미', '정은채', '배누리', '장희령', '이범수', '유연석', '조윤서', '한수연', '최지연', '한태경', '문희경', '차태현', '하성국', '강진아', '김소희', '안재홍', '박수영', '양한열', '이푸름', '신애리', '이경욱', '서지후', '김영웅', '전신환', '장영준', '아이유', '김선호', '박혜영', '김준형', '심희섭', '송덕호', '아오키', '윤제문', '송민경', '한다솔', '박소이', '오달수', '서효림', '고규필'}
# 단순히 중복되지 않은 장르 수 : 20
# 14 {'미스터리', '액션', '스럴리', '기타', '공포', 'SF', '멜로', '스릴러', '범죄', '코미디', '가족', '드라마', '로맨스', '다큐멘터리'}

# %% [markdown]
# - 감독, 출연진, 장르를 기준으로
# - 상위 20%
# - 검색 방식 만들기

# %%
# 파싱한 새로운 column 추가하기

df['parsed_actor'] = df['출연진'].apply(lambda x: split_and_eleminate_by_char(x, ", "))
df['parsed_genre'] = df['장르'].apply(lambda x: split_and_eleminate_by_char(x, ", ·/"))
df['parsed_director'] = df['감독'].apply(lambda x: split_and_eleminate_by_char(x, ", ·/"))
# Out:
# ['권상우', '오정세', '이민정', '박소이', '김준']
# ['지일주', '지연']
# ['정가은']
# ['송민경']
# ['황정민', '현빈', '강기영']
# ['설경구', '이하늬', '박소감', '박해수', '서현우', '김동희']
# ['강수연', '김현주', '류경수']
# ['임선우', '김명찬', '이장유', '박현숙']
# ['김시은', '배두나', '박우영', '정수하']
# ['이동휘', '정은채', '강길우', '정다은']
# ['윤시윤', '설인아', '노상현', '문지인', '이규복', '김영웅']
# ['천우희', '임시완', '김희원']
# ['진선규', '성유빈', '오나라', '고창석', '장동주', '고규필']
# ['신현준', '이문식', '김민경', '홍은기', '최성원']
# ['조은지', '박종환', '곽민규', '소이', '송은지', '곽진무']
# ['유연석', '차태현']
# ['조진웅', '이성민', '김무열']
# ['선동혁', '정아미', '박종진']
# ['김다미', '전소니', '변우석']
# ['신민재', '송보은', '이경욱', '설유진', '현진영', '박동기', '김세환']
# ['강길우', '강진아', '김시은', '변중희', '이한주', '정수지']
# ['오준택', '임지섭', '박해인', '장영준', '방진원', '서지안', '채수아']
# ['박성웅', '이이경', '염혜란', '최민수', '오달수', '윤제문', '백지혜', '서동원', '한다솔']
# ['허준석', '이영석', '남보라']
# ['이설', '박지수']
# ['안재홍', '양한열']
# ['김명임', '김도현', '김순덕', '박유신', '이미경', '최지연', '박혜영']
# ['양홍주', '나현준']
# ['이음', '윤가현', '인내상']
# ['오원빈', '서지희', '심현탁', '박정철', '김수하', '김민', '김봉주', '조수빈', '정병훈']
# ['옥자연', '기윤', '하민호']
# ['박호산', '신애리', '백수련', '이노아', '정혜인', '이용녀']
# ['윤박', '우지현', '박미현', '장희령', '이대연', '박소진', '유인수']
# ['조한선', '정지운', '정태우', '노수산나', '박순천', '정인기', '이지원']
# ['신석호', '하성국', '김승윤', '김민희', '김소령']
# ['박정우', '박영훈']
# ['이하늬', '이선균', '공명', '김상욱']
# ['심희섭', '전혜진', '한승도', '박수영']
# ['유다인', '김다현', '문희경', '김정균', '진혜원', '이지용']
# ['박서준', '아이유', '김종수', '고창석', '정승길', '이현우', '양현민', '홍완표', '허준석', '이하늬']
# ['허지나', '남명렬']
# ['장동윤', '박유나']
# ['차선우', '유지애', '김소희', '이원석', '서지후']
# ['이푸름', '권민혁', '김준형', '심소영', '김모범']
# ['김경일', '양현민', '김소형', '김우겸', '정승길', '조윤서', '신사랑', '오경화', '서벽준', '정유연']
# ['윤성모', '정미미', '장원혁']
# ['박성일', '공민정', '임지호', '전신환', '송덕호', '최준혁', '한태경']
# ['김선영', '이윤지', '최민영', '김용준']
# ['마동석', '이준혁', '아오키', '무네타카', '이범수', '김민재', '이지훈', '김도건', '최동구', '이세호', '고규필', '전석호', '최우준', '한규원', '이태규', '홍준영', '안세호', '강윤', '배누리', '심영은', '김기호']
# ['이나영']
# ['김재화', '조민재', '박강섭']
# ['김강현', '차선우', '한수연', '신연서', '서은채']
# ['소이']
# ['김정팔', '박상욱', '신의현', '이경준', '유재인']
# ['김선호', '강태주', '김강우', '고아라']
# ['이재원', '박상욱', '정서하', '허웅', '안수호']
# ['서효림', '오지호', '김승수', '이설구', '노지유']
# ['정영주', '안미나', '배진아', '한가은']
# ['박성웅', '박선호', '김희정']
# ['기타']
# ['드라마']
# ['멜로', '로맨스']
# ['멜로', '로맨스']
# ['드라마']
# ['액션']
# ['SF']
# ['드라마']
# ['드라마']
# ['드라마']
# ['멜로', '로맨스', '코미디']
# ['스릴러']
# ['드라마']
# ['액션']
# ['드라마']
# ['드라마']
# ['범죄', '드라마']
# ['드라마']
# ['드라마']
# ['드라마']
# ['드라마', '멜로', '로맨스', '가족']
# ['멜로', '로맨스']
# ['코미디', '액션']
# ['드라마']
# ['드라마']
# ['드라마']
# ['다큐멘터리']
# ['드라마']
# ['드라마']
# ['멜로', '로맨스', '드라마']
# ['드라마']
# ['드라마']
# ['드라마']
# ['범죄', '액션', '스럴리']
# ['드라마']
# ['드라마', '멜로']
# ['코미디']
# ['멜로', '로맨스']
# ['드라마']
# ['드라마']
# ['드라마']
# ['멜로', '로맨스', '코미디']
# ['액션']
# ['공포', '미스터리']
# ['코미디']
# ['멜로', '로맨스']
# ['기타']
# ['드라마']
# ['범죄', '액션']
# ['드라마']
# ['코미디']
# ['드라마']
# ['코미디']
# ['드라마']
# ['액션']
# ['공포', '코미디']
# ['액션']
# ['범죄']
# ['스릴러']
# ['마대윤']
# ['이수성']
# ['서동현']
# ['이영용']
# ['임순례']
# ['이해영']
# ['연상호']
# ['주영']
# ['정주리']
# ['형슬우']
# ['임성용']
# ['김태준']
# ['권혁재']
# ['곽정덕']
# ['김덕중']
# ['김주환']
# ['이원태']
# ['이창열']
# ['민용근']
# ['박동기']
# ['최창환']
# ['배인우']
# ['박성광']
# ['임성운']
# ['김현정']
# ['장항준']
# ['이소현']
# ['김성환']
# ['최종태']
# ['한경탁']
# ['이완민']
# ['최세환']
# ['이송희일']
# ['신근호']
# ['홍상수']
# ['양경희']
# ['이원석']
# ['조은성']
# ['양윤모']
# ['이병헌']
# ['문신구']
# ['임재완']
# ['이상훈']
# ['장형모']
# ['[1]']
# ['이현준']
# ['최승연']
# ['가성문']
# ['이상용']
# ['이종필']
# ['김홍기']
# ['황승제']
# ['이황']
# ['최윤호']
# ['박훈정']
# ['최윤호']
# ['신재호']
# ['윤여창']
# ['최주연']

# %%
from typing import TypedDict

class State(TypedDict):
    actor: set[str]
    genre: set[str]
    director: set[str]

def 영화_경험_추천():
    state: State = {}
    state["actor"] = split_and_eleminate_by_char(input("선호하는 배우들을 알려주세요. Ex) 전재준, 박연진, 이사라"), ", ·/")
    state["genre"] = split_and_eleminate_by_char(input("선호하는 장르를 알려주세요. Ex) 로맨스, 공포"), ", ·/")
    state["director"] = split_and_eleminate_by_char(input("선호하는 감독을 알려주세요. Ex) 봉준호"), ", ·/")
    keys = ["actor", "genre", "director"]
    for key in keys:
        if not state.get(key):
            continue
        for value in state.get(key):
            filtered_row = df[df[f"parsed_{key}"].apply(lambda x: value in x)]
            print(f"--- FILTERED {key} ---\n", filtered_row.head(10))

영화_경험_추천()
# Out:
# --- FILTERED actor ---
#             개봉일   제목        배급사   감독  \
# 22  2023-03-29  웅남이  (주)CJ CGV  박성광
#
#                                             출연진       장르  \
# 22  박성웅, 이이경, 염혜란, 최민수, 오달수, 윤제문, 백지혜, 서동원, 한다솔  코미디, 액션
#
#                                      parsed_actor parsed_genre parsed_director
# 22  {박성웅, 서동원, 윤제문, 한다솔, 이이경, 염혜란, 오달수, 백지혜, 최민수}    {코미디, 액션}           {박성광}
# --- FILTERED genre ---
#             개봉일                        제목                 배급사   감독  \
# 2   2023-01-12                별 볼일 없는 인생            (주)이놀미디어  서동현
# 3   2023-01-12                  10일간의 애인              (주)그노스  이영용
# 10  2023-02-08           우리 사랑이 향기로 남을 때  (주)콘텐츠존, (주)다자인소프트  임성용
# 20  2023-03-29                   여섯 개의 밤            (주)인디스토리  최창환
# 21  2023-03-29                  여덟 번째 감각            (주)플레이그램  배인우
# 29  2023-04-06                    솔라 플라워              ㈜스토리제이  한경탁
# 37  2023-04-19                    낭만적 공장            (주)영화사오윈  조은성
# 41  2023-05-10                        롱디        (주)넥스트엔터테인먼트  임재완
# 45  2023-05-18  남자는 처음을 원하고 여자는 마지막을 원한다            (주)스토리제이  이현준
#
#                                            출연진               장르  \
# 2                                          정가은           멜로/로맨스
# 3                                          송민경           멜로/로맨스
# 10                윤시윤, 설인아, 노상현, 문지인, 이규복, 김영웅       멜로·로맨스·코미디
# 20                강길우, 강진아, 김시은, 변중희, 이한주, 정수지  드라마, 멜로·로맨스, 가족
# 21           오준택, 임지섭, 박해인, 장영준, 방진원, 서지안, 채수아           멜로·로맨스
# 29  오원빈, 서지희, 심현탁, 박정철, 김수하, 김민, 김봉주, 조수빈, 정병훈       멜로,로맨스,드라마
# 37                          심희섭, 전혜진, 한승도, 박수영           멜로·로맨스
# 41                                    장동윤, 박유나       멜로·로맨스·코미디
# 45                               윤성모, 정미미, 장원혁           멜로·로맨스
#
#                                     parsed_actor        parsed_genre  \
# 2                                          {정가은}           {멜로, 로맨스}
# 3                                          {송민경}           {멜로, 로맨스}
# 10                {이규복, 설인아, 김영웅, 노상현, 문지인, 윤시윤}      {코미디, 멜로, 로맨스}
# 20                {정수지, 강진아, 이한주, 변중희, 김시은, 강길우}  {드라마, 가족, 멜로, 로맨스}
# 21           {박해인, 장영준, 서지안, 임지섭, 오준택, 채수아, 방진원}           {멜로, 로맨스}
# 29  {정병훈, 김봉주, 김민, 심현탁, 김수하, 박정철, 오원빈, 서지희, 조수빈}      {드라마, 멜로, 로맨스}
# 37                          {한승도, 박수영, 전혜진, 심희섭}           {멜로, 로맨스}
# 41                                    {박유나, 장동윤}      {코미디, 멜로, 로맨스}
# 45                               {정미미, 장원혁, 윤성모}           {멜로, 로맨스}
#
#    parsed_director
# 2            {서동현}
# 3            {이영용}
# 10           {임성용}
# 20           {최창환}
# 21           {배인우}
# 29           {한경탁}
# 37           {조은성}
# 41           {임재완}
# 45           {이현준}
# --- FILTERED director ---
#  Empty DataFrame
# Columns: [개봉일, 제목, 배급사, 감독, 출연진, 장르, parsed_actor, parsed_genre, parsed_director]
# Index: []
